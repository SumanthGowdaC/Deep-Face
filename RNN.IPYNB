# %%
from deepface import DeepFace
import cv2 
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 24-02-01 11:14:54 - Directory C:\Users\Admin/.deepface created
# 24-02-01 11:14:54 - Directory C:\Users\Admin/.deepface/weights created

# %%
img1 = cv2.imread(r'D:\Notes\ML\deepface.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img1, actions = ["emotion"])
# Out:
# 24-02-01 11:16:51 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\Admin\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 16.4MB/s]

# %%
print(result)
# Out:
# [{'emotion': {'angry': 0.2615218982100487, 'disgust': 2.5812299520033832e-08, 'fear': 0.03859710705000907, 'happy': 0.0013706581739825197, 'sad': 0.8900107815861702, 'surprise': 9.0614196324168e-05, 'neutral': 98.80841374397278}, 'dominant_emotion': 'neutral', 'region': {'x': 53, 'y': 27, 'w': 92, 'h': 92}, 'face_confidence': 10.471302064543124}]

# %%
result = DeepFace.analyze(img1, actions = ["race"])
# Out:
# 24-02-01 11:18:07 - race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# To: C:\Users\Admin\.deepface\weights\race_model_single_batch.h5
# 100%|██████████| 537M/537M [00:28<00:00, 18.7MB/s]

# %%
print(result)
# Out:
# [{'race': {'asian': 0.7160641252994537, 'indian': 18.7173530459404, 'black': 0.5699103232473135, 'white': 12.541738152503967, 'middle eastern': 45.54031491279602, 'latino hispanic': 21.91462218761444}, 'dominant_race': 'middle eastern', 'region': {'x': 53, 'y': 27, 'w': 92, 'h': 92}, 'face_confidence': 10.471302064543124}]
